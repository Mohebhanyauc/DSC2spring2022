# %% [markdown]
# This is my first notebook

# %%
import numpy as np

# %%
x = np.random.random(100)
y = print('m') 
y
x
# Out:
# m
# array([0.88724834, 0.12133804, 0.76636743, 0.42208548, 0.11178285,
#        0.92513275, 0.1758397 , 0.26145033, 0.07464639, 0.57459542,
#        0.75416584, 0.53474274, 0.2957452 , 0.35536701, 0.59214916,
#        0.26076337, 0.11888844, 0.00712874, 0.13042192, 0.49114205,
#        0.49553842, 0.08973545, 0.94410027, 0.43622744, 0.34937689,
#        0.37672441, 0.21831348, 0.37734951, 0.76081832, 0.02321149,
#        0.27301429, 0.46304754, 0.62774062, 0.76071561, 0.70047434,
#        0.87427401, 0.35758129, 0.69432048, 0.22838789, 0.52416133,
#        0.09753634, 0.4508467 , 0.65896926, 0.69075456, 0.94066144,
#        0.76186592, 0.08830913, 0.90299411, 0.65255844, 0.32347473,
#        0.06407314, 0.8497073 , 0.419545  , 0.36250492, 0.25479226,
#        0.10781616, 0.37306048, 0.96245469, 0.13145155, 0.04985706,
#        0.53286195, 0.68116825, 0.5489859 , 0.29099448, 0.97995873,
#        0.32619674, 0.47397908, 0.89963229, 0.72736156, 0.78004527,
# ...
